# %%
import pandas as pd
df = pd.read_csv("les-arbres.csv",sep = ";",header = 0)
df.head(10)
# Out:
#      IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT COMPLEMENTADRESSE  \
# 0  102198.0           Arbre      Jardin  PARIS 15E ARRDT               NaN
# 1  106518.0           Arbre      Jardin   PARIS 7E ARRDT               NaN
# 2  106917.0           Arbre      Jardin   PARIS 7E ARRDT               NaN
# 3  107165.0           Arbre      Jardin  PARIS 15E ARRDT               NaN
# 4  108822.0           Arbre      Jardin  PARIS 16E ARRDT               NaN
# 5  109159.0           Arbre      Jardin  PARIS 13E ARRDT               NaN
# 6  109498.0           Arbre      Jardin  PARIS 13E ARRDT               NaN
# 7  130767.0           Arbre      Jardin  PARIS 15E ARRDT               NaN
# 8  139232.0           Arbre      Jardin  PARIS 16E ARRDT               NaN
# 9  139419.0           Arbre      Jardin  PARIS 19E ARRDT               NaN
#
#    NUMERO                                     LIEU / ADRESSE IDEMPLACEMENT  \
# ...

# %%
df_new =  df[(df['HAUTEUR']>=1) & (df['HAUTEUR']<=40)]

# %%
df_new.head(10)
# Out:
#       IDBASE TYPEEMPLACEMENT DOMANIALITE     ARRONDISSEMENT COMPLEMENTADRESSE  \
# 0   102198.0           Arbre      Jardin    PARIS 15E ARRDT               NaN
# 1   106518.0           Arbre      Jardin     PARIS 7E ARRDT               NaN
# 2   106917.0           Arbre      Jardin     PARIS 7E ARRDT               NaN
# 3   107165.0           Arbre      Jardin    PARIS 15E ARRDT               NaN
# 4   108822.0           Arbre      Jardin    PARIS 16E ARRDT               NaN
# 5   109159.0           Arbre      Jardin    PARIS 13E ARRDT               NaN
# 6   109498.0           Arbre      Jardin    PARIS 13E ARRDT               NaN
# 8   139232.0           Arbre      Jardin    PARIS 16E ARRDT               NaN
# 9   139419.0           Arbre      Jardin    PARIS 19E ARRDT               NaN
# 10  140892.0           Arbre   CIMETIERE  SEINE-SAINT-DENIS               NaN
#
#     NUMERO                                     LIEU / ADRESSE IDEMPLACEMENT  \
# ...

# %%
df_new.groupby(['ARRONDISSEMENT','HAUTEUR']).mean()
# Out:
#                                 IDBASE  NUMERO  CIRCONFERENCEENCM  REMARQUABLE
# ARRONDISSEMENT   HAUTEUR
# BOIS DE BOULOGNE 2.0      1.086074e+06     NaN          12.804878          0.0
#                  3.0      1.047210e+06     NaN          19.928571          0.0
#                  4.0      1.305232e+06     NaN          24.224599          0.0
#                  5.0      1.143788e+06     NaN          26.248619          0.0
#                  6.0      9.302759e+05     NaN          38.996337          0.0
# ...                                ...     ...                ...          ...
# VAL-DE-MARNE     31.0     1.619172e+05     NaN         253.833333          0.0
#                  32.0     1.620640e+05     NaN         221.000000          0.0
#                  33.0     1.615040e+05     NaN         309.000000          0.0
#                  34.0     1.614910e+05     NaN         288.000000          0.0
#                  35.0     1.614900e+05     NaN         293.000000          0.0
# ...

# %%
min_df_new = df_new.groupby(['ARRONDISSEMENT','HAUTEUR']).min()

# %%
max_df_new = df_new.groupby(['ARRONDISSEMENT','HAUTEUR']).max()

# %%
min_df_new.head(5)
# Out:
#                           CIRCONFERENCEENCM DOMANIALITE  GENRE    IDBASE  \
# ARRONDISSEMENT   HAUTEUR
# BOIS DE BOULOGNE 2.0                    2.0  Alignement  Pinus  202715.0
#                  3.0                   10.0  Alignement   Acer  204442.0
#                  4.0                   14.0  Alignement   Acer  203828.0
#                  5.0                   17.0  Alignement   Acer  203106.0
#                  6.0                    4.0  Alignement   Acer  203086.0
#
#                          IDEMPLACEMENT                LIEU / ADRESSE  NUMERO  \
# ARRONDISSEMENT   HAUTEUR
# BOIS DE BOULOGNE 2.0         000101005  ALLEE DE LA REINE MARGUERITE     NaN
#                  3.0         000101013  ALLEE DE LA REINE MARGUERITE     NaN
#                  4.0         000101009  ALLEE DE LA REINE MARGUERITE     NaN
#                  5.0         000101001  ALLEE DE LA REINE MARGUERITE     NaN
#                  6.0         000101002  ALLEE DE LA REINE MARGUERITE     NaN
#
# ...

# %%
min_df_new = df_new.groupby(['HAUTEUR','ARRONDISSEMENT']).min()

# %%
arbre_max = df_new['HAUTEUR'].max()

# %%
arbre_min = df_new['HAUTEUR'].min()

# %%
nb_arbre = df_new.groupby(['HAUTEUR']).size().reset_index(name='NUMBERS')

# %%
nb_arbre_arrondissement = df_new.groupby(['HAUTEUR','ARRONDISSEMENT']).size().reset_index(name='NUMBERS')

# %%
nb_arbre_arrondissement.head(10)
# Out:
#    HAUTEUR     ARRONDISSEMENT  NUMBERS
# 0      1.0  BOIS DE VINCENNES       10
# 1      1.0    PARIS 10E ARRDT        3
# 2      1.0    PARIS 11E ARRDT       38
# 3      1.0    PARIS 12E ARRDT       26
# 4      1.0    PARIS 13E ARRDT      144
# 5      1.0    PARIS 14E ARRDT       63
# 6      1.0    PARIS 15E ARRDT       84
# 7      1.0    PARIS 16E ARRDT       59
# 8      1.0    PARIS 17E ARRDT       14
# 9      1.0    PARIS 18E ARRDT      128

# %%
min_df_new = df_new.groupby(['HAUTEUR','ARRONDISSEMENT']).min()

# %%
arbre_haut = df_new[df_new['HAUTEUR']>=30]

# %%
import pandas as pd
df = pd.read_csv("les-arbres.csv",sep = ";",header = 0)
df.head(10)
# Out:
#      IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT COMPLEMENTADRESSE  \
# 0  102198.0           Arbre      Jardin  PARIS 15E ARRDT               NaN
# 1  106518.0           Arbre      Jardin   PARIS 7E ARRDT               NaN
# 2  106917.0           Arbre      Jardin   PARIS 7E ARRDT               NaN
# 3  107165.0           Arbre      Jardin  PARIS 15E ARRDT               NaN
# 4  108822.0           Arbre      Jardin  PARIS 16E ARRDT               NaN
# 5  109159.0           Arbre      Jardin  PARIS 13E ARRDT               NaN
# 6  109498.0           Arbre      Jardin  PARIS 13E ARRDT               NaN
# 7  130767.0           Arbre      Jardin  PARIS 15E ARRDT               NaN
# 8  139232.0           Arbre      Jardin  PARIS 16E ARRDT               NaN
# 9  139419.0           Arbre      Jardin  PARIS 19E ARRDT               NaN
#
#    NUMERO                                     LIEU / ADRESSE IDEMPLACEMENT  \
# ...

# %%
df_new =  df[(df['HAUTEUR']>=1) & (df['HAUTEUR']<=40)]

# %%
hauteur_classe = []

for i in df_new.HAUTEUR:
    if i >= 1 and i < 16:
        hauteur_classe.append('0-15 M')
    elif i >= 16 and i < 26:
        hauteur_classe.append('16-25 M')
    else:
        hauteur_classe.append('+25 M')

df_new['hauteur_classe_col']=[i for i in hauteur_classe]

df_new['hauteur_classe_col']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# 0         0-15 M
# 1         0-15 M
# 2         0-15 M
# 3         0-15 M
# 4         0-15 M
#            ...
# 203521    0-15 M
# 203522    0-15 M
# 203523    0-15 M
# 203524    0-15 M
# 203529    0-15 M
# Name: hauteur_classe_col, Length: 168903, dtype: object

# %%
df_new['HAUTEUR']
# Out:
# 0         13.0
# 1         11.0
# 2          9.0
# 3          3.0
# 4          6.0
#           ...
# 203521     6.0
# 203522     5.0
# 203523    10.0
# 203524     4.0
# 203529     6.0
# Name: HAUTEUR, Length: 168903, dtype: float64

# %%
print(df_new.loc[(df_new['HAUTEUR'] > 35) & (df_new['ARRONDISSEMENT'] == "PARIS 16E ARRDT"),:])
# Out:
#           IDBASE TYPEEMPLACEMENT DOMANIALITE   ARRONDISSEMENT  \
# 12077   263504.0           Arbre  Alignement  PARIS 16E ARRDT
# 69184   244067.0           Arbre  Alignement  PARIS 16E ARRDT
# 107332  252120.0           Arbre  Alignement  PARIS 16E ARRDT
# 124051  243800.0           Arbre  Alignement  PARIS 16E ARRDT
#
#        COMPLEMENTADRESSE  NUMERO                LIEU / ADRESSE IDEMPLACEMENT  \
# 12077                NaN     NaN                AVENUE D EYLAU     000101003
# 69184                NaN     NaN  AVENUE DE LA PORTE D AUTEUIL     000404037
# 107332               NaN     NaN            CHAUSSEE LA MUETTE     000501007
# 124051               NaN     NaN  AVENUE DE LA PORTE D AUTEUIL     000301043
#
#        LIBELLEFRANCAIS     GENRE         ESPECE VARIETEOUCULTIVAR  \
# 12077       Marronnier  Aesculus  hippocastanum       'Baumannii'
# 69184       Marronnier  Aesculus  hippocastanum       'Baumannii'
# 107332      Marronnier  Aesculus  hippocastanum               NaN
# ...

# %%
df_new.drop(['TYPEEMPLACEMENT','DOMANIALITE','COMPLEMENTADRESSE','LIEU / ADRESSE','IDEMPLACEMENT','VARIETEOUCULTIVAR','CIRCONFERENCEENCM','STADEDEVELOPPEMENT','IDBASE','REMARQUABLE'], axis = 1)
# Out:
#          ARRONDISSEMENT  NUMERO   LIBELLEFRANCAIS     GENRE         ESPECE  \
# 0       PARIS 15E ARRDT     NaN           Tilleul     Tilia         n. sp.
# 1        PARIS 7E ARRDT     NaN           Platane  Platanus    x hispanica
# 2        PARIS 7E ARRDT     NaN           Pommier     Malus         n. sp.
# 3       PARIS 15E ARRDT     NaN             Frêne  Fraxinus         n. sp.
# 4       PARIS 16E ARRDT     NaN           Tilleul     Tilia      tomentosa
# ...                 ...     ...               ...       ...            ...
# 203521   PARIS 6E ARRDT     NaN        Marronnier  Aesculus  hippocastanum
# 203522  PARIS 13E ARRDT     NaN           Sophora   Sophora       japonica
# 203523  PARIS 20E ARRDT     NaN             Frêne  Fraxinus      excelsior
# 203524  PARIS 12E ARRDT     NaN            Mûrier     Morus           alba
# 203529  PARIS 15E ARRDT     NaN  Poirier à fleurs     Pyrus     calleryana
#
#         HAUTEUR                  geo_point_2d hauteur_classe_col
# ...

# %%
df_hauteur_arr = df_new.groupby(["ARRONDISSEMENT"])['hauteur_classe_col']
print(df_hauteur_arr)

# %%
df_hauteur_arr.value_counts()
# Out:
# ARRONDISSEMENT     hauteur_classe_col
# BOIS DE BOULOGNE   0-15 M                3168
#                    16-25 M                778
#                    +25 M                  120
# BOIS DE VINCENNES  0-15 M                6254
#                    16-25 M               2105
#                                          ...
# SEINE-SAINT-DENIS  16-25 M                758
#                    +25 M                    3
# VAL-DE-MARNE       0-15 M                2361
#                    16-25 M               1032
#                    +25 M                  426
# Name: hauteur_classe_col, Length: 73, dtype: int64

# %%
df_hauteur_arr.value_counts().plot.bar()

# %%
df_hauteur_arr.value_counts(hauteur_classe_col(0,15)).plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1efcdede68dd> in <module>
# ----> 1 df_hauteur_arr.value_counts(hauteur_classe_col(0,15)).plot.bar()
#
# NameError: name 'hauteur_classe_col' is not defined

# %%
df_tem=df_new.groupby('hauteur_classe_col')['hauteur_classe_col'].count()
print(df_tem)

# %%
df_espece = df_new.groupby(["ARRONDISSEMENT"])['ESPECE']

# %%
import pandas as pd
df = pd.read_csv("les-arbres.csv",sep = ";",header = 0)

# %%
df_new =  df[(df['HAUTEUR']>=1) & (df['HAUTEUR']<=40)]

# %%
df_espece = df_new.groupby(["ARRONDISSEMENT"])['ESPECE']

# %%
df_espece.value_counts()

# %%
import matplotlib as mp 
df_espece.value_counts().plot()
df_espece.xlabel(df_espece['ESPECE'].count)
df_espece.ylabel(df_espece['ARRONDISSEMENT'])
df_espece.title('Histogramme group by arrondissement especes')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-cc27bcb187c9> in <module>
#       1 import matplotlib as mp
#       2 df_espece.value_counts().hist()
# ----> 3 df_espece.xlabel(df_espece['ESPECE'].count)
#       4 df_espece.ylabel(df_espece['ARRONDISSEMENT'])
#       5 df_espece.title('Histogramme group by arrondissement especes')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     564
#     565         raise AttributeError(
# --> 566             "%r object has no attribute %r" % (type(self).__name__, attr)
#     567         )
#     568
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'xlabel'

# %%
x = [1, 2, 2, 3, 4, 4, 4, 4, 4, 5, 5]
pyplot.hist(x, range = (0, 5), bins = 5, color = 'yellow',
            edgecolor = 'red')
pyplot.xlabel('valeurs')
pyplot.ylabel('nombres')
pyplot.title('Exemple d\' histogramme simple')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-c10b9fd613ac> in <module>
#       1 x = [1, 2, 2, 3, 4, 4, 4, 4, 4, 5, 5]
# ----> 2 pyplot.hist(x, range = (0, 5), bins = 5, color = 'yellow',
#       3             edgecolor = 'red')
#       4 pyplot.xlabel('valeurs')
#       5 pyplot.ylabel('nombres')
#
# NameError: name 'pyplot' is not defined
